# %% [markdown]
# # Machine Learning LAB 7: CLUSTERING - K-means and DBSCAN
#
# Course 2024/25: *F. Chiariotti*
#
# The notebook contains some simple tasks about **CLUSTERING**.
#
# Complete all the **required code sections**.
#
# ### IMPORTANT for the exam:
#
# The functions you might be required to implement in the exam will have the same signature and parameters as the ones in the labs

# %% [markdown]
# ## Image segmentation with k-means
#
# In this laboratory we will use the k-means algorithm to cluster a dataset of 3D points. We will apply **K-means** to the problem of image compression and image segmentation. The main idea is to apply k-means to the colors of the pixels of an image to select the k most representative colors. Then, we will replace each pixel color with the closest representative color. This will allow us to reduce the number of colors in the image and compress it. A color is a vector of 3 values (R,G,B) that represent the amount of red, green and blue in the color; this implies that each pixel is a point in a 3D space.
#
# In particular you are going to implement the k-means algorithm from scratch and to compare the results with the implementation already present in the sklearn library.
#
# In the second part of the laboratory we will use a **linkage-based** clustering algorithm to cluster a dataset of 2D points and compare it with the results obtained with k-means.
#
# ---

# %% [markdown]
# ## Import all the necessary Python libraries

# %%
# %matplotlib inline  

import numpy as np
import typing as tp
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.cluster import KMeans, AgglomerativeClustering
from matplotlib import pyplot as plt

np.random.seed(20)

# %% [markdown]
# ---

# %% [markdown]
# ## Define the heplper functions
#
# In this section you will find some helper functions (some already implemented, some to be implemented by you) that will be used in the following sections.
# 1. `img_plot` -> function to plot an image with name and dimension as title,
# 2. `scatter_plot` -> function to plot a scatter plot of the data,
# 3. `scatter_plot_2d` -> function to plot a 2D scatter plot of the data,
# 4. `error_plot` -> function to plot the error of the k-means algorithm over the iterations,
# 5. `cluster_plot` -> function to plot the obtained clusters.
#
# **DO NOT CHANGE THE PRE-WRITTEN CODE UNLESS OTHERWISE SPECIFIED**

# %%
def img_plot(img: np.ndarray, title: str = None) -> None:
    """
    Plot an image
    :param img: image to plot
    :param title: title of the plot
    """
    
    plt.figure()
    plt.imshow(img)
    plt.axis('off')
    if title is not None:
        plt.title(f'{title}: {img.shape}')
    plt.tight_layout()
    plt.show()
    plt.close()

# %%
def scatter_plot(data: np.ndarray, clusters: np.ndarray = None, centers: np.ndarray = None, title: str = None) -> None:
    """
    Plot a scatter plot of the data
    :param data: data to plot
    :param clusters: cluster labels
    :param centers: cluster centers
    :param title: title of the plot
    """
    
    fig = plt.figure()
    axis = fig.add_subplot(1, 1, 1, projection="3d")
    axis.set_xlabel("Red")
    axis.set_ylabel("Green")
    axis.set_zlabel("Blue", rotation=90, labelpad=-1)
    if title is not None:
        plt.title(title)
    if clusters is None:
        axis.scatter(data[:,0], data[:,1], data[:,2], marker="o", c=data, s=5)
    else:
        axis.scatter(data[:,0], data[:,1], data[:,2], marker="o", c=clusters, s=1, cmap='viridis', zorder=0, alpha=0.5 )
    if centers is not None:
        axis.scatter(centers[:,0], centers[:,1], centers[:,2], c='red', s=400, zorder=10)
    plt.tight_layout()
    plt.show()
    plt.close()

# %%
def scatter_plot_2d(x: np.ndarray, y: np.ndarray = None, centers: np.ndarray = None, title: str = None) -> None:
    """
    Plot a scatter plot of the data
    :param x: data to plot
    :param y: cluster labels
    :param centers: cluster centers
    :param title: title of the plot
    """

    fig = plt.figure()
    plt.scatter(x[:,0], x[:,1], c=y, marker="o", s=10, cmap='viridis')
    plt.scatter(centers[:,0], centers[:,1], c='black', s=200, alpha=0.5)
    if title is not None:
        plt.title(title)
    plt.tight_layout()
    plt.show()
    plt.close()

# %%
def error_plot(errors: np.ndarray, labels: np.ndarray = None) -> None:
    """
    Plot the errors over the iterations
    :param errors: errors to plot
    """
    
    if labels is None:
        plt.plot(errors[1:-1])
        plt.plot(errors[1:-1], 'ro')
    else:
        plt.plot(labels, errors)
        plt.plot(labels, errors, 'ro')
    plt.title('Error over iterations')
    plt.ylabel('Error')
    plt.xlabel('Iteration #')
    plt.grid()
    plt.tight_layout()
    plt.show()
    plt.close()

# %%
def cluster_plot(labels: np.ndarray, x: np.ndarray, title: str = None) -> None:
    """
    Plot the clusters
    :param labels: cluster labels
    :param x: data
    :param title: title of the plot
    """
    
    # Black removed and is used for noise instead.
    unique_labels = set(labels)
    colors = [plt.cm.Spectral(each)
            for each in np.linspace(0, 1, len(unique_labels))]
    for k, col in zip(unique_labels, colors):
        if k == -1:
            # Black used for noise.
            col = [0, 0, 0, 1]

        class_member_mask = (labels == k)

        xy = x[class_member_mask ]
        plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
                markeredgecolor='k', markersize=14)

        xy = x[class_member_mask ]
        plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
                markeredgecolor='k', markersize=6)

    if title is not None:
        plt.title(title)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## A) K-means clustering
#
# Implement the K-means algorithm

# %%
# Load the provided image and display it (if you like you can experiment with other images)
# To load the images use the function plt.imread(<path_to_iamge>)
santa = plt.imread("data/santaclaus2.jpg")

# Plot the image with its shape
img_plot(santa)
print(santa.shape)
# Out:
# (172, 256, 3)

# %%
# Reshape the data to a matrix of num_pixels x 3 
# (divide by 255 to have colors in [0 1] range for plotting functions of sklearn)
santa_reshaped = np.reshape(santa, (santa.shape[0]*santa.shape[1],santa.shape[2]))
santa_reshaped = santa_reshaped /255

# Print the shape of the data and the min and max values of the pixels
print("shape:",santa_reshaped.shape, "min:", np.min(santa_reshaped),"max:", np.max(santa_reshaped))
# Out:
# shape: (44032, 3) min: 0.0 max: 1.0

# %%
mean = np.mean(santa_reshaped, axis = 0)
std = np.std(santa_reshaped, axis = 0)

rd = np.random.normal(loc = mean, scale = std, size = (1000, 3))
print(mean)
print(np.mean(rd, axis = 0))

rd[0]
# Out:
# [0.3383916  0.46236106 0.43494375]
# [0.34626207 0.46599205 0.4310208 ]
# array([0.63235626, 0.51077027, 0.52513738])

# %% [markdown]
# Plot the points in the 3-dimensional space with normalized intervals between 0 and 1 (corresponding to the three channels of the image, i.e. Red Green and Blue)

# %%
# Sugestion: use the function scatter_plot()
scatter_plot(santa_reshaped)

# %% [markdown]
# Implement the k-means algorithm manually (**do not use the kmeans function of sklearn and do not download implementations from other web sources**). The inputs to the function is the set of vectors to be clustered and the number of clusters. The output must contain:
# - the clusters barycenters,
# - a vector associating each data point to the corresponding cluster *(the labels)* and
# - the error (value of the cost function) at each iteration.
#
# Additionally, fix a maximum number of iterations of the k-means algorithm (e.g., 50).
#
# Be careful about the initalization, you can use some random points from the training set, or get random values but ensure they are in the proper range. Poor initalizations can lead to the failure of the algorithm (in particular check that no cluster is initialized as empty, otherwise the algorithm can not update it).

# %%
def kmeans(points: np.ndarray, k: int, max_iters: int = 50) -> tp.Tuple[np.ndarray, np.ndarray, list]:
    """
    Perform K-means clustering
    :param points: data points
    :param k: number of clusters
    :param max_iters: maximum number of iterations
    """

    # TODO Generate random centroids
    # Hint: Use the correct means and standard deviation to ensure they represent the whole input space
    point_count = points.shape[0]
    coord_count = points.shape[1]
    clusters = np.ndarray((point_count,)) # this will contain the labels
    ##
    mean = np.mean(points, axis = 0)
    std = np.std(points, axis = 0)
    centroids = np.random.normal(loc = mean, scale = std, size = (k, coord_count))
    ##
    prev_error = 1e9+1
    error = [1e9]
    
    # Run the K-means algorithm: until the estimate of centroid is stable (or the maximum number of iterations is reached)
    iters = 0
    while (error[iters] != prev_error) and iters < max_iters:
        # TODO Measure the distance to every centroid
        distances = np.array([[np.linalg.norm(point - centroid) for centroid in centroids] for point in points])
        # TODO Step 1: assign training data to closest centroid
        clusters = np.argmin(distances, axis = 1)
        # TODO Calculate the new centroids for every cluster
        cluster_points = [points[clusters == k_idx, ] for k_idx in range(k)]
        for k_idx in range(k):
            pps = cluster_points[k_idx]
            if (pps.shape[0] > 0):
                centroids[k_idx, ] = np.sum(pps, axis = 0)/pps.shape[0] 
            else:
                centroids[k_idx, ] = np.random.normal(loc = mean, scale = std, size = (1, coord_count))
        prev_error = error[iters]
        current_error = 0 
        # TODO Update the total cost estimate
        current_error = np.sum([np.linalg.norm(point - centroids[clusters[i]]) for i, point in enumerate(points)])
        error.append(current_error)
        # Update the iteration counter
        iters += 1

    return centroids, clusters, error

# %% [markdown]
# Now try the function you developed on the Santaclaus image with three clusters (k=3), then plot the data points in the 3-dimensional space, each point must be coloured based on the membership to one of the clusters. Additionally, plot the respective clusters centroids (use a different shape, size or color to highlight the centroids). Also, plot the total cost over each iteration

# %%
# Run your K-means function on the data
kmeans_centroids, kmeans_clusters, kmeans_errors = kmeans(santa_reshaped, k=3)

# Print the errors:
print(kmeans_errors)
# Plot the results
scatter_plot(santa_reshaped, kmeans_clusters, kmeans_centroids)

# Plot the error
error_plot(kmeans_errors)
# Out:
# [1000000000.0, np.float64(7672.265891107242), np.float64(7478.256287982255), np.float64(7496.158009835659), np.float64(7493.906186933936), np.float64(7489.640239498699), np.float64(7487.636161550987), np.float64(7485.486233592598), np.float64(7485.58646552638), np.float64(7485.618023780721), np.float64(7485.618023780721)]

# %% [markdown]
# Now use the k-means function provided in sklearn. Pass to the function the number of clusters and use multiple random initializations (n_init parameter). Go to the documentation page for further details

# %%
# Define the K-means model
km = KMeans(n_clusters=3,n_init=100)

# Fit the model to the data
santa_predicted = km.fit_predict(santa_reshaped)
santa_reshaped_compressed = np.copy(santa_reshaped)
for i in range(santa_reshaped_compressed.shape[0]):
    santa_reshaped_compressed[i]=km.cluster_centers_[santa_predicted[i]]

# Get the cluster centers
centers = km.cluster_centers_

# %% [markdown]
# Perform the same plot as above but with the output of the k-means function provided in sklearn.

# %%
scatter_plot(santa_reshaped, santa_predicted, centers)

# %% [markdown]
# ### TO DO [Answer the following]
#
# Compare the results obtained with your implementation and with k-means from sklearn. Do you observe any differences, *i.e.*, do the two plots match?

# %% [markdown]
# **ANSWER:**
#
# The two plots match. My solution is almost identical to that obtained with the sklearn implementation.

# %% [markdown]
# Now display the segmented image based on the clusters found above with the k-means functions by sklearn and by your own K-means implementation.

# %%
# Extract the color values of the centers
color_centers = centers*255

# Reshape the data to the original image shape
santa_processed = np.reshape(santa_reshaped_compressed, santa.shape)

# Plot the recolored image
img_plot(santa_processed)

# Extract the color values of the centers
kmeans_color_centers = kmeans_centroids*255

# Reshape the data to the original image shape
kmeans_santa_reshaped_compressed = np.copy(santa_reshaped)
for i in range(kmeans_santa_reshaped_compressed.shape[0]):
    kmeans_santa_reshaped_compressed[i]=kmeans_centroids[int(kmeans_clusters[i])]
kmeans_santa_processed = np.reshape(kmeans_santa_reshaped_compressed, santa.shape)

# Plot the recolored image
img_plot(kmeans_santa_processed)

# %% [markdown]
# ## B) DBSCAN clustering
#
# Now, let's try DBSCAN: implement the algorithm with $\varepsilon=0.1$ and $M=10$ (i.e., the minimum number of neighbors).
#
# The output should be a **list of indices** for all points, indicating which cluster each point belongs to.
#
# Outliers are in cluster 0, all other points have a positive index.
#
# For efficiency, we should compute a distance matrix first. Additionally, since DBSCAN is much more complex, we will try it on a smaller dataset.

# %%
# Load sample data
data = np.load("data/moon_data.npz")

# Extract data
x = data['X']
print(x)
labels_true = data['labels_true']
# Out:
# [[-0.51671142  0.12336816]
#  [-1.05205683  1.21547148]
#  [-0.62674339 -0.09401812]
#  ...
#  [ 1.36142844 -1.12026291]
#  [ 0.4792162   0.76152417]
#  [-0.37279003 -0.22398523]]

# %%
clusters = np.array([1, 2, -1, 1, -1])
a =np.where(clusters == -1)[0]
a
# Out:
# array([2, 4])

# %%
def distance_matrix(points):
    point_count = points.shape[0]
    distances = np.zeros((point_count, point_count))
    for i in range(point_count):
        array_points = np.asarray(points - points[i, :])
        distances[i, :] = np.linalg.norm(array_points,axis=1)
        distances[i,i] = 1e9
    return distances


def find_neighbors(distances, epsilon):
    return np.where(distances < epsilon)[0] # returns the indexes of the points (row number)


def dbscan(points, epsilon, M):
    point_count = points.shape[0]
    coord_count = points.shape[1]
    distances = distance_matrix(points)
    print(point_count)
    C = 0 # cluster idx (to be incremented)
    done = False
    # The clusters vector contains the assigned cluster values: -1 means unassigned, 0 means outlier, clusters have >=1 values
    clusters = -np.ones(point_count)
    while (not done):
        # TODO While there are still unassigned points, iterate over them
        unassigned_idxs = np.where(clusters == -1)[0]
        if (len(unassigned_idxs) > 0):
            idx = unassigned_idxs[0]
            # For each unassigned point, check if it is an outlier, expand over its neighbors if it is not                   
            neigh_idxs = find_neighbors(distances[idx, ], epsilon)
            clusters[idx] = 0
            if len(neigh_idxs) >= M:
                C = C + 1
                print(f"Clusters: {C}")
                clusters[idx] = C
                idxs_to_scan = neigh_idxs.copy()
                while len(idxs_to_scan) > 0:
                    print(f"neighbours to scan: {len(idxs_to_scan)}")
                    n_idx = idxs_to_scan[0]
                    print(f"scannig point: {n_idx}")
                    if clusters[n_idx] == 0:
                        # if it was assigned to noise, change to C and continue
                        # (no need to expand over its neighbourhood because it is not a "core" point,
                        # i.e. a point with >= M neighbours)
                        clusters[n_idx] = C
                    # if it already belongs somewhere, do not change its label
                    #
                    if clusters[n_idx] < 0:
                        # if it is still unassigned, change its label to C and check if
                        # it is a "core" point.
                        # if a core point, add all its neighbours to the list of points to scan
                        clusters[n_idx] = C
                        their_neighbour = find_neighbors(distances[n_idx, ], epsilon)
                        if len(their_neighbour) >= M:
                            idxs_to_scan = np.union1d(idxs_to_scan, their_neighbour)
                    # then remove the current point from those to scan
                    idxs_to_scan = np.setdiff1d(idxs_to_scan, np.array([n_idx]))
        else:
            done = True
    return clusters

# %% [markdown]
# Let's try and plot it! Noise points will be in red. How do the clusters look like?

# %%
clusters = dbscan(x, epsilon=0.1, M=10)
cluster_plot(clusters,x)
# Out:
# 1500
# Clusters: 1
# neighbours to scan: 17
# scannig point: 10
# neighbours to scan: 22
# scannig point: 0
# neighbours to scan: 21
# scannig point: 51
# neighbours to scan: 21
# scannig point: 0
# neighbours to scan: 20
# scannig point: 64
# neighbours to scan: 26
# scannig point: 0
# neighbours to scan: 25
# scannig point: 51
# neighbours to scan: 24
# scannig point: 197
# neighbours to scan: 32
# scannig point: 0
# neighbours to scan: 31
# scannig point: 10
# neighbours to scan: 30
# scannig point: 51
# neighbours to scan: 29
# scannig point: 64
# neighbours to scan: 28
# scannig point: 214
# neighbours to scan: 34
# scannig point: 64
# neighbours to scan: 33
# scannig point: 94
# neighbours to scan: 40
# scannig point: 2
# neighbours to scan: 39
# scannig point: 36
# neighbours to scan: 38
# scannig point: 76
# neighbours to scan: 41
# scannig point: 2
# neighbours to scan: 40
# scannig point: 94
# neighbours to scan: 39
# scannig point: 108
# neighbours to scan: 42
# scannig point: 76
# neighbours to scan: 41
# scannig point: 94
# neighbours to scan: 40
# scannig point: 214
# neighbours to scan: 39
# scannig point: 284
# neighbours to scan: 42
# scannig point: 10
# neighbours to scan: 41
# scannig point: 197
# neighbours to scan: 40
# scannig point: 287
# neighbours to scan: 46
# scannig point: 10
# neighbours to scan: 45
# scannig point: 73
# neighbours to scan: 50
# scannig point: 178
# neighbours to scan: 51
# scannig point: 73
# neighbours to scan: 50
# scannig point: 197
# neighbours to scan: 49
# scannig point: 284
# neighbours to scan: 48
# scannig point: 287
# neighbours to scan: 47
# scannig point: 321
# neighbours to scan: 54
# scannig point: 66
# neighbours to scan: 53
# scannig point: 97
# neighbours to scan: 59
# scannig point: 82
# neighbours to scan: 62
# scannig point: 87
# neighbours to scan: 62
# scannig point: 82
# neighbours to scan: 61
# scannig point: 97
# neighbours to scan: 60
# scannig point: 108
# neighbours to scan: 59
# scannig point: 128
# neighbours to scan: 60
# scannig point: 82
# neighbours to scan: 59
# scannig point: 97
# neighbours to scan: 58
# scannig point: 163
# neighbours to scan: 61
# scannig point: 82
# neighbours to scan: 60
# scannig point: 87
# neighbours to scan: 59
# scannig point: 97
# neighbours to scan: 58
# scannig point: 128
# neighbours to scan: 57
# scannig point: 321
# neighbours to scan: 56
# scannig point: 338
# neighbours to scan: 59
# scannig point: 2
# neighbours to scan: 58
# scannig point: 76
# neighbours to scan: 57
# scannig point: 94
# neighbours to scan: 56
# scannig point: 108
# neighbours to scan: 55
# scannig point: 383
# neighbours to scan: 60
# scannig point: 0
# neighbours to scan: 59
# scannig point: 10
# neighbours to scan: 58
# scannig point: 51
# neighbours to scan: 57
# scannig point: 64
# neighbours to scan: 56
# scannig point: 197
# neighbours to scan: 55
# scannig point: 214
# neighbours to scan: 54
# scannig point: 439
# neighbours to scan: 60
# scannig point: 73
# neighbours to scan: 59
# scannig point: 178
# neighbours to scan: 58
# scannig point: 331
# neighbours to scan: 62
# scannig point: 426
# neighbours to scan: 67
# scannig point: 331
# neighbours to scan: 66
# scannig point: 437
# neighbours to scan: 66
# scannig point: 331
# neighbours to scan: 65
# scannig point: 439
# neighbours to scan: 64
# scannig point: 450
# neighbours to scan: 71
# scannig point: 76
# neighbours to scan: 70
# scannig point: 87
# neighbours to scan: 69
# scannig point: 97
# neighbours to scan: 68
# scannig point: 108
# neighbours to scan: 67
# scannig point: 128
# neighbours to scan: 66
# scannig point: 163
# neighbours to scan: 65
# scannig point: 321
# neighbours to scan: 64
# scannig point: 338
# neighbours to scan: 63
# scannig point: 456
# neighbours to scan: 62
# scannig point: 477
# neighbours to scan: 68
# scannig point: 2
# neighbours to scan: 67
# scannig point: 76
# neighbours to scan: 66
# scannig point: 94
# neighbours to scan: 65
# scannig point: 108
# neighbours to scan: 64
# scannig point: 214
# neighbours to scan: 63
# scannig point: 338
# neighbours to scan: 62
# scannig point: 450
# neighbours to scan: 61
# scannig point: 478
# neighbours to scan: 65
# scannig point: 73
# neighbours to scan: 64
# scannig point: 178
# neighbours to scan: 63
# scannig point: 331
# neighbours to scan: 62
# scannig point: 437
# neighbours to scan: 61
# scannig point: 439
# neighbours to scan: 60
# scannig point: 491
# neighbours to scan: 64
# scannig point: 73
# neighbours to scan: 63
# scannig point: 331
# neighbours to scan: 62
# scannig point: 437
# neighbours to scan: 61
# scannig point: 439
# neighbours to scan: 60
# scannig point: 478
# neighbours to scan: 59
# scannig point: 500
# neighbours to scan: 68
# scannig point: 3
# neighbours to scan: 67
# scannig point: 35
# neighbours to scan: 79
# scannig point: 82
# neighbours to scan: 78
# scannig point: 87
# neighbours to scan: 77
# scannig point: 97
# neighbours to scan: 76
# scannig point: 124
# neighbours to scan: 78
# scannig point: 35
# neighbours to scan: 77
# scannig point: 128
# neighbours to scan: 76
# scannig point: 163
# neighbours to scan: 75
# scannig point: 167
# neighbours to scan: 76
# scannig point: 3
# neighbours to scan: 75
# scannig point: 35
# neighbours to scan: 74
# scannig point: 185
# neighbours to scan: 77
# scannig point: 4
# neighbours to scan: 100
# scannig point: 224
# neighbours to scan: 99
# scannig point: 289
# neighbours to scan: 98
# scannig point: 312
# neighbours to scan: 97
# scannig point: 322
# neighbours to scan: 96
# scannig point: 348
# neighbours to scan: 95
# scannig point: 422
# neighbours to scan: 94
# scannig point: 428
# neighbours to scan: 93
# scannig point: 445
# neighbours to scan: 92
# scannig point: 530
# neighbours to scan: 102
# scannig point: 85
# neighbours to scan: 101
# scannig point: 147
# neighbours to scan: 100
# scannig point: 189
# neighbours to scan: 99
# scannig point: 209
# neighbours to scan: 98
# scannig point: 248
# neighbours to scan: 97
# scannig point: 267
# neighbours to scan: 96
# scannig point: 277
# neighbours to scan: 95
# scannig point: 305
# neighbours to scan: 94
# scannig point: 345
# neighbours to scan: 93
# scannig point: 392
# neighbours to scan: 92
# scannig point: 497
# neighbours to scan: 91
# scannig point: 560
# neighbours to scan: 98
# scannig point: 66
# neighbours to scan: 97
# scannig point: 82
# neighbours to scan: 96
# scannig point: 97
# neighbours to scan: 95
# scannig point: 128
# neighbours to scan: 94
# scannig point: 163
# neighbours to scan: 93
# scannig point: 321
# neighbours to scan: 92
# scannig point: 450
# neighbours to scan: 91
# scannig point: 569
# neighbours to scan: 97
# scannig point: 64
# neighbours to scan: 96
# scannig point: 94
# neighbours to scan: 95
# scannig point: 108
# neighbours to scan: 94
# scannig point: 214
# neighbours to scan: 93
# scannig point: 338
# neighbours to scan: 92
# scannig point: 477
# neighbours to scan: 91
# scannig point: 510
# neighbours to scan: 90
# scannig point: 577
# neighbours to scan: 95
# scannig point: 97
# neighbours to scan: 94
# scannig point: 124
# neighbours to scan: 93
# scannig point: 128
# neighbours to scan: 92
# scannig point: 163
# neighbours to scan: 91
# scannig point: 500
# neighbours to scan: 90
# scannig point: 560
# neighbours to scan: 89
# scannig point: 601
# neighbours to scan: 96
# scannig point: 76
# neighbours to scan: 95
# scannig point: 94
# neighbours to scan: 94
# scannig point: 97
# neighbours to scan: 93
# scannig point: 108
# neighbours to scan: 92
# scannig point: 321
# neighbours to scan: 91
# scannig point: 338
# neighbours to scan: 90
# scannig point: 450
# neighbours to scan: 89
# scannig point: 477
# neighbours to scan: 88
# scannig point: 605
# neighbours to scan: 98
# scannig point: 4
# neighbours to scan: 97
# scannig point: 115
# neighbours to scan: 96
# scannig point: 147
# neighbours to scan: 95
# scannig point: 150
# neighbours to scan: 94
# scannig point: 185
# neighbours to scan: 93
# scannig point: 204
# neighbours to scan: 92
# scannig point: 209
# neighbours to scan: 91
# scannig point: 277
# neighbours to scan: 90
# scannig point: 345
# neighbours to scan: 89
# scannig point: 392
# neighbours to scan: 88
# scannig point: 497
# neighbours to scan: 87
# scannig point: 606
# neighbours to scan: 89
# scannig point: 10
# neighbours to scan: 88
# scannig point: 284
# neighbours to scan: 87
# scannig point: 501
# neighbours to scan: 86
# scannig point: 618
# neighbours to scan: 85
# scannig point: 622
# neighbours to scan: 92
# scannig point: 331
# neighbours to scan: 91
# scannig point: 426
# neighbours to scan: 90
# scannig point: 437
# neighbours to scan: 89
# scannig point: 439
# scannig point: 741
# neighbours to scan: 27
# scannig point: 742
# neighbours to scan: 26
# scannig point: 829
# neighbours to scan: 25
# scannig point: 855
# neighbours to scan: 24
# scannig point: 867
# neighbours to scan: 23
# scannig point: 1150
# neighbours to scan: 22
# scannig point: 1192
# neighbours to scan: 21
# scannig point: 1226
# neighbours to scan: 20
# scannig point: 1269
# neighbours to scan: 19
# scannig point: 1299
# neighbours to scan: 18
# scannig point: 1306
# neighbours to scan: 17
# scannig point: 1326
# neighbours to scan: 16
# scannig point: 1398
# neighbours to scan: 15
# scannig point: 1407
# neighbours to scan: 14
# scannig point: 1472
# neighbours to scan: 31
# scannig point: 18
# neighbours to scan: 30
# scannig point: 58
# neighbours to scan: 29
# scannig point: 69
# neighbours to scan: 28
# scannig point: 460
# neighbours to scan: 27
# scannig point: 540
# neighbours to scan: 26
# scannig point: 576
# neighbours to scan: 25
# scannig point: 608
# neighbours to scan: 24
# scannig point: 776
# neighbours to scan: 23
# scannig point: 824
# neighbours to scan: 22
# scannig point: 930
# neighbours to scan: 21
# scannig point: 979
# neighbours to scan: 20
# scannig point: 1003
# neighbours to scan: 19
# scannig point: 1069
# neighbours to scan: 18
# scannig point: 1072
# neighbours to scan: 17
# scannig point: 1143
# neighbours to scan: 16
# scannig point: 1254
# neighbours to scan: 15
# scannig point: 1400
# neighbours to scan: 14
# scannig point: 1411
# neighbours to scan: 13
# scannig point: 1477
# neighbours to scan: 29
# scannig point: 173
# neighbours to scan: 28
# scannig point: 191
# neighbours to scan: 27
# scannig point: 250
# neighbours to scan: 26
# scannig point: 311
# neighbours to scan: 25
# scannig point: 470
# neighbours to scan: 24
# scannig point: 544
# neighbours to scan: 23
# scannig point: 567
# neighbours to scan: 22
# scannig point: 574
# neighbours to scan: 21
# scannig point: 583
# neighbours to scan: 20
# scannig point: 710
# neighbours to scan: 19
# scannig point: 1039
# neighbours to scan: 18
# scannig point: 1047
# neighbours to scan: 17
# scannig point: 1052
# neighbours to scan: 16
# scannig point: 1113
# neighbours to scan: 15
# scannig point: 1171
# neighbours to scan: 14
# scannig point: 1320
# neighbours to scan: 13
# scannig point: 1429
# neighbours to scan: 12
# scannig point: 1478
# neighbours to scan: 25
# scannig point: 40
# neighbours to scan: 24
# scannig point: 41
# neighbours to scan: 23
# scannig point: 53
# neighbours to scan: 22
# scannig point: 286
# neighbours to scan: 21
# scannig point: 406
# neighbours to scan: 20
# scannig point: 564
# neighbours to scan: 19
# scannig point: 582
# neighbours to scan: 18
# scannig point: 671
# neighbours to scan: 17
# scannig point: 875
# neighbours to scan: 16
# scannig point: 928
# neighbours to scan: 15
# scannig point: 973
# neighbours to scan: 14
# scannig point: 974
# neighbours to scan: 13
# scannig point: 1020
# neighbours to scan: 12
# scannig point: 1424
# neighbours to scan: 11
# scannig point: 1480
# neighbours to scan: 34
# scannig point: 271
# neighbours to scan: 33
# scannig point: 309
# neighbours to scan: 32
# scannig point: 317
# neighbours to scan: 31
# scannig point: 405
# neighbours to scan: 30
# scannig point: 436
# neighbours to scan: 29
# scannig point: 498
# neighbours to scan: 28
# scannig point: 543
# neighbours to scan: 27
# scannig point: 604
# neighbours to scan: 26
# scannig point: 648
# neighbours to scan: 25
# scannig point: 743
# neighbours to scan: 24
# scannig point: 814
# neighbours to scan: 23
# scannig point: 845
# neighbours to scan: 22
# scannig point: 859
# neighbours to scan: 21
# scannig point: 862
# neighbours to scan: 20
# scannig point: 921
# neighbours to scan: 19
# scannig point: 925
# neighbours to scan: 18
# scannig point: 1028
# neighbours to scan: 17
# scannig point: 1034
# neighbours to scan: 16
# scannig point: 1117
# neighbours to scan: 15
# scannig point: 1126
# neighbours to scan: 14
# scannig point: 1135
# neighbours to scan: 13
# scannig point: 1158
# neighbours to scan: 12
# scannig point: 1291
# neighbours to scan: 11
# scannig point: 1461
# neighbours to scan: 10
# scannig point: 1482
# neighbours to scan: 9
# scannig point: 1483
# neighbours to scan: 23
# scannig point: 44
# neighbours to scan: 22
# scannig point: 45
# neighbours to scan: 21
# scannig point: 282
# neighbours to scan: 20
# scannig point: 435
# neighbours to scan: 19
# scannig point: 469
# neighbours to scan: 18
# scannig point: 533
# neighbours to scan: 17
# scannig point: 546
# neighbours to scan: 16
# scannig point: 565
# neighbours to scan: 15
# scannig point: 663
# neighbours to scan: 14
# scannig point: 718
# neighbours to scan: 13
# scannig point: 987
# neighbours to scan: 12
# scannig point: 1014
# neighbours to scan: 11
# scannig point: 1154
# neighbours to scan: 10
# scannig point: 1350
# neighbours to scan: 9
# scannig point: 1420
# neighbours to scan: 8
# scannig point: 1488
# neighbours to scan: 25
# scannig point: 116
# neighbours to scan: 24
# scannig point: 164
# neighbours to scan: 23
# scannig point: 168
# neighbours to scan: 22
# scannig point: 272
# neighbours to scan: 21
# scannig point: 355
# neighbours to scan: 20
# scannig point: 364
# neighbours to scan: 19
# scannig point: 378
# neighbours to scan: 18
# scannig point: 596
# neighbours to scan: 17
# scannig point: 682
# neighbours to scan: 16
# scannig point: 735
# neighbours to scan: 15
# scannig point: 909
# neighbours to scan: 14
# scannig point: 962
# neighbours to scan: 13
# scannig point: 1011
# neighbours to scan: 12
# scannig point: 1107
# neighbours to scan: 11
# scannig point: 1146
# neighbours to scan: 10
# scannig point: 1284
# neighbours to scan: 9
# scannig point: 1292
# neighbours to scan: 8
# scannig point: 1314
# neighbours to scan: 7
# scannig point: 1489
# neighbours to scan: 25
# scannig point: 103
# neighbours to scan: 24
# scannig point: 173
# neighbours to scan: 23
# scannig point: 191
# neighbours to scan: 22
# scannig point: 250
# neighbours to scan: 21
# scannig point: 311
# neighbours to scan: 20
# scannig point: 399
# neighbours to scan: 19
# scannig point: 470
# neighbours to scan: 18
# scannig point: 499
# neighbours to scan: 17
# scannig point: 544
# neighbours to scan: 16
# scannig point: 574
# neighbours to scan: 15
# scannig point: 583
# neighbours to scan: 14
# scannig point: 710
# neighbours to scan: 13
# scannig point: 1047
# neighbours to scan: 12
# scannig point: 1052
# neighbours to scan: 11
# scannig point: 1113
# neighbours to scan: 10
# scannig point: 1171
# neighbours to scan: 9
# scannig point: 1320
# neighbours to scan: 8
# scannig point: 1429
# neighbours to scan: 7
# scannig point: 1477
# neighbours to scan: 6
# scannig point: 1491
# neighbours to scan: 5
# scannig point: 1492
# neighbours to scan: 18
# scannig point: 1
# neighbours to scan: 17
# scannig point: 111
# neighbours to scan: 16
# scannig point: 430
# neighbours to scan: 15
# scannig point: 473
# neighbours to scan: 14
# scannig point: 634
# neighbours to scan: 13
# scannig point: 665
# neighbours to scan: 12
# scannig point: 691
# neighbours to scan: 11
# scannig point: 814
# neighbours to scan: 10
# scannig point: 853
# neighbours to scan: 9
# scannig point: 993
# neighbours to scan: 8
# scannig point: 1034
# neighbours to scan: 7
# scannig point: 1095
# neighbours to scan: 6
# scannig point: 1145
# neighbours to scan: 5
# scannig point: 1291
# neighbours to scan: 4
# scannig point: 1493
# neighbours to scan: 21
# scannig point: 162
# neighbours to scan: 20
# scannig point: 319
# neighbours to scan: 19
# scannig point: 339
# neighbours to scan: 18
# scannig point: 361
# neighbours to scan: 17
# scannig point: 458
# neighbours to scan: 16
# scannig point: 522
# neighbours to scan: 15
# scannig point: 656
# neighbours to scan: 14
# scannig point: 713
# neighbours to scan: 13
# scannig point: 719
# neighbours to scan: 12
# scannig point: 802
# neighbours to scan: 11
# scannig point: 900
# neighbours to scan: 10
# scannig point: 1036
# neighbours to scan: 9
# scannig point: 1075
# neighbours to scan: 8
# scannig point: 1099
# neighbours to scan: 7
# scannig point: 1152
# neighbours to scan: 6
# scannig point: 1193
# neighbours to scan: 5
# scannig point: 1195
# neighbours to scan: 4
# scannig point: 1245
# neighbours to scan: 3
# scannig point: 1494
# neighbours to scan: 21
# scannig point: 9
# neighbours to scan: 20
# scannig point: 24
# neighbours to scan: 19
# scannig point: 175
# neighbours to scan: 18
# scannig point: 315
# neighbours to scan: 17
# scannig point: 480
# neighbours to scan: 16
# scannig point: 525
# neighbours to scan: 15
# scannig point: 782
# neighbours to scan: 14
# scannig point: 832
# neighbours to scan: 13
# scannig point: 863
# neighbours to scan: 12
# scannig point: 871
# neighbours to scan: 11
# scannig point: 906
# neighbours to scan: 10
# scannig point: 964
# neighbours to scan: 9
# scannig point: 990
# neighbours to scan: 8
# scannig point: 1006
# neighbours to scan: 7
# scannig point: 1261
# neighbours to scan: 6
# scannig point: 1310
# neighbours to scan: 5
# scannig point: 1321
# neighbours to scan: 4
# scannig point: 1344
# neighbours to scan: 3
# scannig point: 1389
# neighbours to scan: 2
# scannig point: 1495
# neighbours to scan: 14
# scannig point: 28
# neighbours to scan: 13
# scannig point: 442
# neighbours to scan: 12
# scannig point: 590
# neighbours to scan: 11
# scannig point: 610
# neighbours to scan: 10
# scannig point: 615
# neighbours to scan: 9
# scannig point: 727
# neighbours to scan: 8
# scannig point: 926
# neighbours to scan: 7
# scannig point: 1017
# neighbours to scan: 6
# scannig point: 1037
# neighbours to scan: 5
# scannig point: 1053
# neighbours to scan: 4
# scannig point: 1142
# neighbours to scan: 3
# scannig point: 1337
# neighbours to scan: 2
# scannig point: 1380
# neighbours to scan: 1
# scannig point: 1498

# %% [markdown]
# ---
